# %%
# Experiment- 3

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# read audio samples
input_data = read("aud.wav")
audio = input_data[1]

plt.plot(audio[0:])

plt.ylabel("Amplitude")
plt.xlabel("Time")
 
plt.title("Sample Wav")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft
from scipy.io import wavfile

sample_rate, audio_time_series = wavfile.read("aud.wav")
single_sample_data = audio_time_series[:sample_rate]

def fft_plot(audio, sample_rate):
  N = len(audio)    # Number of samples
  T = 1/sample_rate # Period
  y_freq = fft(audio)
  domain = len(y_freq) // 2
  x_freq = np.linspace(0, sample_rate//2, N//2)
  plt.plot(x_freq, abs(y_freq[:domain]))
  plt.xlabel("Frequency [Hz]")
  plt.ylabel("Frequency Amplitude |X(t)|")
  return plt.show()

fft_plot(single_sample_data, sample_rate)

# %%
sample_rate, audio_time_series = wavfile.read("aud.wav")
single_sample_data = audio_time_series[:sample_rate]

def fft_plot(audio, sample_rate):
  N = len(audio)    # Number of samples
  y_freq = fft(audio)
  domain = len(y_freq) // 2
  x_freq = np.linspace(0, sample_rate//2, N//2)
  # Changed from abs(y_freq[:domain]) -> y_freq[:domain]
  plt.plot(x_freq, y_freq[:domain])
  plt.xlabel("Frequency [Hz]")
  plt.ylabel("Frequency Amplitude |X(t)|")
  return plt.show()

# Changed from single_sample_data -> audio_time_series
fft_plot(audio_time_series, sample_rate)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
import numpy as np
import scipy
import pylab
import matplotlib
import soundfile
matplotlib.use('tkagg')

audio_samples, sample_rate = soundfile.read("aud.wav", dtype = 'int16')
number_samples = len(audio_samples)
freq_bins = np.arange(number_samples//2)*sample_rate/number_samples
print('Frequency bins: ', freq_bins)    
print("Maximum Frequency ", np.max(freq_bins))
print("Minimum Frquency ", np.min(freq_bins))
# Out:
# Frequency bins:  [ 0.00000000e+00  9.14257851e-02  1.82851570e-01 ... -5.42196596e+02
#  -5.42105170e+02 -5.42013744e+02]
# Maximum Frequency  4090.3008822588263
# Minimum Frquency  -4090.295518612766

# %%
new = abs(freq_bins)
print(np.min(new))
# Out:
# 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavefile
sample_rate, samples = wavfile.read('aud.wav')

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(samples, Fs=sample_rate)
plt.show()

# %%
from scipy import signal
from scipy.io import wavfile
import numpy as np

sample_rate, samples = wavfile.read('aud.wav')
fft_samples = np.abs(np.fft.fft(samples))

peak_index=np.argmax(fft_samples) # get indices of the largest amplitude
max_frequency = peak_index / (len(samples)) * sample_rate

print(
    f"""
    Frequency index where the maximum is:
    {peak_index}
    
    Maximum Frequency:
    {str(max_frequency)} Hz

    """
    )
# Out:
#     Frequency index where the maximum is:
#     2484
#
#     Maximum Frequency:
#     227.1016502354214 Hz
